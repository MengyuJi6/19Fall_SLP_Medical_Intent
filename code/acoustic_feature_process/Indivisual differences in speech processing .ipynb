# %%
import numpy as np
import glob
import pandas as pd

# %%
overview_info = pd.read_csv('/Users/jifeng/Desktop/Medical Speech, Transcription, and Intent/overview-of-recordings-processed.csv') 
overview_info.head()
# Out:
#    audio_clipping  audio_clipping:confidence background_noise_audible  \
# 0     no_clipping                     1.0000              light_noise
# 1  light_clipping                     0.6803                 no_noise
# 2     no_clipping                     1.0000                 no_noise
# 3     no_clipping                     1.0000              light_noise
# 4     no_clipping                     1.0000                 no_noise
#
#    background_noise_audible:confidence  overall_quality_of_the_audio  \
# 0                               1.0000                          3.33
# 1                               0.6803                          3.33
# 2                               0.6655                          3.33
# 3                               1.0000                          3.33
# 4                               1.0000                          4.67
#
#      quiet_speaker  quiet_speaker:confidence  speaker_id  \
# 0  audible_speaker                       1.0    43453425
# ...

# %%
audioInfo = overview_info[['file_name', 'speaker_id', 'audio_clipping:confidence', 'background_noise_audible:confidence', 'quiet_speaker:confidence']]
audioInfo.head()
# Out:
#                        file_name  speaker_id  audio_clipping:confidence  \
# 0  1249120_43453425_58166571.wav    43453425                     1.0000
# 1  1249120_43719934_43347848.wav    43719934                     0.6803
# 2  1249120_43719934_53187202.wav    43719934                     1.0000
# 3  1249120_31349958_55816195.wav    31349958                     1.0000
# 4  1249120_43719934_82524191.wav    43719934                     1.0000
#
#    background_noise_audible:confidence  quiet_speaker:confidence
# 0                               1.0000                       1.0
# 1                               0.6803                       1.0
# 2                               0.6655                       1.0
# 3                               1.0000                       1.0
# 4                               1.0000                       1.0

# %%
accoustic_feature_val = pd.read_csv("/Users/jifeng/Desktop/Medical Speech, Transcription, and Intent/speech_based_features_validate.csv") 
accoustic_feature_val.head()
# Out:
#                        file_name              prompt   min_pitch   max_pitch  \
# 0  1249120_44415714_12774994.wav           Neurology   78.960488  586.083123
# 1  1249120_44323331_89529293.wav          Skin issue   67.085631  265.574298
# 2  1249120_44263136_64809479.wav  Surgery department  113.102808  350.504244
# 3  1249120_44259428_83019694.wav  Surgery department  136.101579  408.116907
# 4  1249120_44259428_45992221.wav   Internal medicine  138.689022  338.115379
#
#    mean_pitch    sd_pitch  min_intensity  max_intensity  mean_intensity  \
# 0  358.558766  216.946396      47.360107      67.600516       56.505255
# 1  222.706882   34.352334      41.683808      69.047418       47.021752
# 2  213.739187   60.818785      49.890429      80.923762       60.740634
# 3  202.427680   71.801224      47.640439      93.335920       67.605979
# 4  190.793265   35.596125      48.654581      93.145937       64.718609
#
#    sd_intensity    jitter   shimmer        hnr  speakingRate
# ...

# %%
accoustic_feature = pd.read_csv("/Users/jifeng/Desktop/Medical Speech, Transcription, and Intent/speech_based_features.csv") 
accoustic_feature.head()
# Out:
#                        file_name              prompt   min_pitch   max_pitch  \
# 0  1249120_43453425_58166571.wav       Mental health   95.675619  594.109521
# 1  1249120_43719934_43347848.wav          Skin issue  137.636090  521.001369
# 2  1249120_43719934_53187202.wav   Internal medicine  156.661407  335.239721
# 3  1249120_31349958_55816195.wav  Surgery department   77.290737  288.786560
# 4  1249120_43719934_82524191.wav  Surgery department  151.830750  308.311522
#
#    mean_pitch    sd_pitch  min_intensity  max_intensity  mean_intensity  \
# 0  107.154572   39.179107      46.875236      72.366905       61.632222
# 1  280.669723  131.720778      16.658803      75.699944       48.308705
# 2  232.726225   48.063326      15.119231      75.296643       45.497202
# 3  208.510205   33.502824      62.104997      84.525180       73.004235
# 4  233.725843   37.709111      22.637201      81.652301       56.731989
#
#    sd_intensity    jitter   shimmer        hnr  speakingRate
# ...

# %%
accoustic_feature_test = pd.read_csv("/Users/jifeng/Desktop/Medical Speech, Transcription, and Intent/speech_based_features_test.csv") 
accoustic_feature_test.head()
# Out:
#                         file_name             prompt   min_pitch   max_pitch  \
# 0   1249120_44197979_23991689.wav  Internal medicine   68.453348  161.533049
# 1   1249120_44174241_12756709.wav              Other  120.869621  263.754124
# 2  1249120_44197979_109954671.wav              Other  130.969036  531.194575
# 3   1249120_44246595_34981278.wav  Internal medicine   68.790690  360.504047
# 4   1249120_44176037_93714115.wav              Other   75.883040  585.852963
#
#    mean_pitch    sd_pitch  min_intensity  max_intensity  mean_intensity  \
# 0  143.508053   13.823605      55.391307      73.748759       67.540701
# 1  139.351445   26.941824      48.607551      91.259985       70.750471
# 2  226.542896  144.364111      53.036405      74.391877       62.777643
# 3  227.038545   52.031419       8.719557      69.854322       48.222494
# 4  185.539416   58.789188      53.203235      85.963022       69.339623
#
#    sd_intensity    jitter   shimmer        hnr  speakingRate
# ...

# %%
info_audio = accoustic_feature.merge(audioInfo, on='file_name', how='left')
info_audio.head()
# Out:
#                        file_name              prompt   min_pitch   max_pitch  \
# 0  1249120_43453425_58166571.wav       Mental health   95.675619  594.109521
# 1  1249120_43719934_43347848.wav          Skin issue  137.636090  521.001369
# 2  1249120_43719934_53187202.wav   Internal medicine  156.661407  335.239721
# 3  1249120_31349958_55816195.wav  Surgery department   77.290737  288.786560
# 4  1249120_43719934_82524191.wav  Surgery department  151.830750  308.311522
#
#    mean_pitch    sd_pitch  min_intensity  max_intensity  mean_intensity  \
# 0  107.154572   39.179107      46.875236      72.366905       61.632222
# 1  280.669723  131.720778      16.658803      75.699944       48.308705
# 2  232.726225   48.063326      15.119231      75.296643       45.497202
# 3  208.510205   33.502824      62.104997      84.525180       73.004235
# 4  233.725843   37.709111      22.637201      81.652301       56.731989
#
# ...

# %%
info_audio_val = accoustic_feature_val.merge(audioInfo, on='file_name', how='left')
info_audio_val.head()
# Out:
#                        file_name              prompt   min_pitch   max_pitch  \
# 0  1249120_44415714_12774994.wav           Neurology   78.960488  586.083123
# 1  1249120_44323331_89529293.wav          Skin issue   67.085631  265.574298
# 2  1249120_44263136_64809479.wav  Surgery department  113.102808  350.504244
# 3  1249120_44259428_83019694.wav  Surgery department  136.101579  408.116907
# 4  1249120_44259428_45992221.wav   Internal medicine  138.689022  338.115379
#
#    mean_pitch    sd_pitch  min_intensity  max_intensity  mean_intensity  \
# 0  358.558766  216.946396      47.360107      67.600516       56.505255
# 1  222.706882   34.352334      41.683808      69.047418       47.021752
# 2  213.739187   60.818785      49.890429      80.923762       60.740634
# 3  202.427680   71.801224      47.640439      93.335920       67.605979
# 4  190.793265   35.596125      48.654581      93.145937       64.718609
#
# ...

# %%
info_audio_test = accoustic_feature_test.merge(audioInfo, on='file_name', how='left')
info_audio_test.head()
# Out:
#                         file_name             prompt   min_pitch   max_pitch  \
# 0   1249120_44197979_23991689.wav  Internal medicine   68.453348  161.533049
# 1   1249120_44174241_12756709.wav              Other  120.869621  263.754124
# 2  1249120_44197979_109954671.wav              Other  130.969036  531.194575
# 3   1249120_44246595_34981278.wav  Internal medicine   68.790690  360.504047
# 4   1249120_44176037_93714115.wav              Other   75.883040  585.852963
#
#    mean_pitch    sd_pitch  min_intensity  max_intensity  mean_intensity  \
# 0  143.508053   13.823605      55.391307      73.748759       67.540701
# 1  139.351445   26.941824      48.607551      91.259985       70.750471
# 2  226.542896  144.364111      53.036405      74.391877       62.777643
# 3  227.038545   52.031419       8.719557      69.854322       48.222494
# 4  185.539416   58.789188      53.203235      85.963022       69.339623
#
# ...

# %%
accoustic_speaker = info_audio[['file_name', 'speaker_id', 'min_pitch', 'max_pitch', 'mean_pitch', 'sd_pitch', 'min_intensity', 'max_intensity', 'mean_intensity', 'sd_intensity', 'jitter', 'shimmer', 
                               'hnr', 'speakingRate']]
accoustic_speaker.head()
# Out:
#                        file_name  speaker_id   min_pitch   max_pitch  \
# 0  1249120_43453425_58166571.wav    43453425   95.675619  594.109521
# 1  1249120_43719934_43347848.wav    43719934  137.636090  521.001369
# 2  1249120_43719934_53187202.wav    43719934  156.661407  335.239721
# 3  1249120_31349958_55816195.wav    31349958   77.290737  288.786560
# 4  1249120_43719934_82524191.wav    43719934  151.830750  308.311522
#
#    mean_pitch    sd_pitch  min_intensity  max_intensity  mean_intensity  \
# 0  107.154572   39.179107      46.875236      72.366905       61.632222
# 1  280.669723  131.720778      16.658803      75.699944       48.308705
# 2  232.726225   48.063326      15.119231      75.296643       45.497202
# 3  208.510205   33.502824      62.104997      84.525180       73.004235
# 4  233.725843   37.709111      22.637201      81.652301       56.731989
#
#    sd_intensity    jitter   shimmer        hnr  speakingRate
# ...

# %%
accoustic_speaker_val = info_audio_val[['file_name', 'speaker_id', 'min_pitch', 'max_pitch', 'mean_pitch', 'sd_pitch', 'min_intensity', 'max_intensity', 'mean_intensity', 'sd_intensity', 'jitter', 'shimmer', 
                               'hnr', 'speakingRate']]
accoustic_speaker_val.head()
# Out:
#                        file_name  speaker_id   min_pitch   max_pitch  \
# 0  1249120_44415714_12774994.wav    44415714   78.960488  586.083123
# 1  1249120_44323331_89529293.wav    44323331   67.085631  265.574298
# 2  1249120_44263136_64809479.wav    44263136  113.102808  350.504244
# 3  1249120_44259428_83019694.wav    44259428  136.101579  408.116907
# 4  1249120_44259428_45992221.wav    44259428  138.689022  338.115379
#
#    mean_pitch    sd_pitch  min_intensity  max_intensity  mean_intensity  \
# 0  358.558766  216.946396      47.360107      67.600516       56.505255
# 1  222.706882   34.352334      41.683808      69.047418       47.021752
# 2  213.739187   60.818785      49.890429      80.923762       60.740634
# 3  202.427680   71.801224      47.640439      93.335920       67.605979
# 4  190.793265   35.596125      48.654581      93.145937       64.718609
#
#    sd_intensity    jitter   shimmer        hnr  speakingRate
# ...

# %%
accoustic_speaker_test = info_audio_test[['file_name', 'speaker_id', 'min_pitch', 'max_pitch', 'mean_pitch', 'sd_pitch', 'min_intensity', 'max_intensity', 'mean_intensity', 'sd_intensity', 'jitter', 'shimmer', 
                               'hnr', 'speakingRate']]
accoustic_speaker_test.head()
# Out:
#                         file_name  speaker_id   min_pitch   max_pitch  \
# 0   1249120_44197979_23991689.wav    44197979   68.453348  161.533049
# 1   1249120_44174241_12756709.wav    44174241  120.869621  263.754124
# 2  1249120_44197979_109954671.wav    44197979  130.969036  531.194575
# 3   1249120_44246595_34981278.wav    44246595   68.790690  360.504047
# 4   1249120_44176037_93714115.wav    44176037   75.883040  585.852963
#
#    mean_pitch    sd_pitch  min_intensity  max_intensity  mean_intensity  \
# 0  143.508053   13.823605      55.391307      73.748759       67.540701
# 1  139.351445   26.941824      48.607551      91.259985       70.750471
# 2  226.542896  144.364111      53.036405      74.391877       62.777643
# 3  227.038545   52.031419       8.719557      69.854322       48.222494
# 4  185.539416   58.789188      53.203235      85.963022       69.339623
#
#    sd_intensity    jitter   shimmer        hnr  speakingRate
# ...

# %%
cols = [col for col in accoustic_speaker.columns if col not in['file_name']]
gp_col = 'speaker_id'
accoustic_speaker_mean = accoustic_speaker.groupby(gp_col)[cols].mean()

# %%
cols_val = [col for col in accoustic_speaker_val.columns if col not in['file_name']]
gp_col_val = 'speaker_id'
accoustic_speaker_mean_val = accoustic_speaker_val.groupby(gp_col_val)[cols_val].mean()

# %%
cols_test = [col for col in accoustic_speaker_test.columns if col not in['file_name']]
gp_col_test = 'speaker_id'
accoustic_speaker_mean_test = accoustic_speaker_test.groupby(gp_col_test)[cols_test].mean()

# %%
accoustic_speaker_mean.to_csv("/Users/jifeng/Desktop/Medical Speech, Transcription, and Intent/mean_based_on_speaker_id.csv", index=False)

# %%
accoustic_speaker_mean_val.to_csv("/Users/jifeng/Desktop/Medical Speech, Transcription, and Intent/mean_based_on_speaker_id_validate.csv", index=False)

# %%
accoustic_speaker_mean_test.to_csv("/Users/jifeng/Desktop/Medical Speech, Transcription, and Intent/mean_based_on_speaker_id_test.csv", index=False)

# %%
accoustic_feature_mean = pd.read_csv("/Users/jifeng/Desktop/Medical Speech, Transcription, and Intent/mean_based_on_speaker_id.csv") 
accoustic_feature_mean.head()
# Out:
#    speaker_id   min_pitch   max_pitch  mean_pitch   sd_pitch  min_intensity  \
# 0     1853182  112.255776  372.636699  197.494993  50.709687      -2.803199
# 1     2171654  126.001137  422.928002  201.462654  49.012905      17.970780
# 2     6338946   92.470759  285.271398  145.680794  28.856346      24.112032
# 3    13842059   99.774242  521.244803  135.250661  65.945993      52.470595
# 4    14054543   98.049883  392.312832  154.655028  42.795908      33.951302
#
#    max_intensity  mean_intensity  sd_intensity    jitter   shimmer        hnr  \
# 0      66.923926       38.228481     20.365119  0.008432  0.116619   8.479246
# 1      63.470294       47.913631     11.802738  0.007497  0.158237   7.964328
# 2      83.036244       61.223675     17.263624  0.008876  0.096468  10.525596
# 3      83.710756       70.256422      8.910830  0.010000  0.112426  11.429793
# 4      67.162738       48.944845      8.319954  0.009216  0.130790  11.516097
#
#    speakingRate
# 0      3.094480
# ...

# %%
accoustic_feature_mean_val = pd.read_csv("/Users/jifeng/Desktop/Medical Speech, Transcription, and Intent/mean_based_on_speaker_id_validate.csv") 
accoustic_feature_mean_val.head()
# Out:
#    speaker_id   min_pitch   max_pitch  mean_pitch   sd_pitch  min_intensity  \
# 0    44246595  129.975691  405.860063  240.461497  54.601606       5.756627
# 1    44259428  107.322642  463.496340  181.038201  59.752306      47.656863
# 2    44263136   81.354509  445.421524  166.315059  73.598932      56.276387
# 3    44273314   96.003385  394.414943  155.818119  49.418490      42.371654
# 4    44292353   90.804693  378.332872  128.318467  52.712712      12.163750
#
#    max_intensity  mean_intensity  sd_intensity    jitter   shimmer        hnr  \
# 0      69.900588       46.640921     17.256683  0.006979  0.109216  10.817530
# 1      92.873310       68.358116     17.050317  0.008525  0.098263  11.490474
# 2      83.470057       66.552622      6.466111  0.015814  0.162424   9.841193
# 3      81.634224       61.656636     12.264724  0.011515  0.152425  11.627645
# 4      74.796178       53.798261     16.776883  0.009681  0.128133  12.864588
#
#    speakingRate
# 0      2.752365
# ...

# %%
accoustic_feature_mean_test = pd.read_csv("/Users/jifeng/Desktop/Medical Speech, Transcription, and Intent/mean_based_on_speaker_id_test.csv") 
accoustic_feature_mean_test.head()
# Out:
#    speaker_id   min_pitch   max_pitch  mean_pitch   sd_pitch  min_intensity  \
# 0    44142156  116.650160  422.103446  176.494343  42.609754      25.681254
# 1    44160489   96.239645  462.707788  161.933965  58.194149      52.465074
# 2    44174241  104.135112  344.343038  148.206759  41.074017      51.477345
# 3    44176037   79.126559  437.585273  189.504938  53.504865      53.927245
# 4    44188922   76.547303  296.015634   97.367051  33.161384      43.643576
#
#    max_intensity  mean_intensity  sd_intensity    jitter   shimmer        hnr  \
# 0      71.587298       50.053587     13.929934  0.006872  0.120464  13.952854
# 1      89.198503       67.292657     10.242722  0.009208  0.115921  11.915197
# 2      90.994878       72.076151     13.051818  0.008904  0.088981  10.283944
# 3      85.900292       69.545284      9.034895  0.008577  0.138516  10.200572
# 4      79.960547       63.902681     10.989440  0.014982  0.170396   8.959007
#
#    speakingRate
# 0      1.987438
# ...

# %%
processed_file_name = []
processed_speaker_id = []
processed_min_pitch_list = []
processed_max_pitch_list = []
processed_mean_pitch_list = []
processed_sd_pitch_list = []
processed_min_intensity_list = []
processed_max_intensity_list = []
processed_mean_intensity_list = []
processed_sd_intensity_list = []
processed_jitter_list = []
processed_shimmer_list = []
processed_hnr_list = []
processed_speakingRate_list = []

# %%
for index_mean, row_mean in accoustic_feature_mean.iterrows():
    for index, row in accoustic_speaker.iterrows():
        if row_mean.speaker_id == row.speaker_id:
            processed_file_name.append(row.file_name)
            processed_speaker_id.append(row.speaker_id)
            processed_min_pitch_list.append(row.min_pitch - row_mean.min_pitch)
            processed_max_pitch_list.append(row.max_pitch - row_mean.max_pitch)
            processed_mean_pitch_list.append(row.mean_pitch - row_mean.mean_pitch)
            processed_sd_pitch_list.append(row.sd_pitch - row_mean.sd_pitch)      
            processed_min_intensity_list.append(row.min_intensity - row_mean.min_intensity)
            processed_max_intensity_list.append(row.max_intensity - row_mean.max_intensity)
            processed_mean_intensity_list.append(row.mean_intensity - row_mean.mean_intensity)
            processed_sd_intensity_list.append(row.sd_intensity - row_mean.sd_intensity)
            processed_jitter_list.append(row.jitter- row_mean.jitter)
            processed_shimmer_list.append(row.shimmer- row_mean.shimmer)
            processed_hnr_list.append(row.hnr- row_mean.hnr)
            processed_speakingRate_list.append(row.speakingRate- row_mean.speakingRate)

# %%
processed_file_name_val = []
processed_speaker_id_val = []
processed_min_pitch_list_val = []
processed_max_pitch_list_val = []
processed_mean_pitch_list_val = []
processed_sd_pitch_list_val = []
processed_min_intensity_list_val = []
processed_max_intensity_list_val = []
processed_mean_intensity_list_val = []
processed_sd_intensity_list_val = []
processed_jitter_list_val = []
processed_shimmer_list_val = []
processed_hnr_list_val = []
processed_speakingRate_list_val = []

# %%
for index_mean, row_mean in accoustic_feature_mean_val.iterrows():
    for index, row in accoustic_speaker_val.iterrows():
        if row_mean.speaker_id == row.speaker_id:
            processed_file_name_val.append(row.file_name)
            processed_speaker_id_val.append(row.speaker_id)
            processed_min_pitch_list_val.append(row.min_pitch - row_mean.min_pitch)
            processed_max_pitch_list_val.append(row.max_pitch - row_mean.max_pitch)
            processed_mean_pitch_list_val.append(row.mean_pitch - row_mean.mean_pitch)
            processed_sd_pitch_list_val.append(row.sd_pitch - row_mean.sd_pitch)      
            processed_min_intensity_list_val.append(row.min_intensity - row_mean.min_intensity)
            processed_max_intensity_list_val.append(row.max_intensity - row_mean.max_intensity)
            processed_mean_intensity_list_val.append(row.mean_intensity - row_mean.mean_intensity)
            processed_sd_intensity_list_val.append(row.sd_intensity - row_mean.sd_intensity)
            processed_jitter_list_val.append(row.jitter- row_mean.jitter)
            processed_shimmer_list_val.append(row.shimmer- row_mean.shimmer)
            processed_hnr_list_val.append(row.hnr- row_mean.hnr)
            processed_speakingRate_list_val.append(row.speakingRate- row_mean.speakingRate)

# %%
processed_file_name_test = []
processed_speaker_id_test = []
processed_min_pitch_list_test = []
processed_max_pitch_list_test = []
processed_mean_pitch_list_test = []
processed_sd_pitch_list_test = []
processed_min_intensity_list_test = []
processed_max_intensity_list_test = []
processed_mean_intensity_list_test = []
processed_sd_intensity_list_test = []
processed_jitter_list_test = []
processed_shimmer_list_test = []
processed_hnr_list_test = []
processed_speakingRate_list_test = []

# %%
for index_mean, row_mean in accoustic_feature_mean_test.iterrows():
    for index, row in accoustic_speaker_test.iterrows():
        if row_mean.speaker_id == row.speaker_id:
            processed_file_name_test.append(row.file_name)
            processed_speaker_id_test.append(row.speaker_id)
            processed_min_pitch_list_test.append(row.min_pitch - row_mean.min_pitch)
            processed_max_pitch_list_test.append(row.max_pitch - row_mean.max_pitch)
            processed_mean_pitch_list_test.append(row.mean_pitch - row_mean.mean_pitch)
            processed_sd_pitch_list_test.append(row.sd_pitch - row_mean.sd_pitch)      
            processed_min_intensity_list_test.append(row.min_intensity - row_mean.min_intensity)
            processed_max_intensity_list_test.append(row.max_intensity - row_mean.max_intensity)
            processed_mean_intensity_list_test.append(row.mean_intensity - row_mean.mean_intensity)
            processed_sd_intensity_list_test.append(row.sd_intensity - row_mean.sd_intensity)
            processed_jitter_list_test.append(row.jitter- row_mean.jitter)
            processed_shimmer_list_test.append(row.shimmer- row_mean.shimmer)
            processed_hnr_list_test.append(row.hnr- row_mean.hnr)
            processed_speakingRate_list_test.append(row.speakingRate- row_mean.speakingRate)

# %%
processed_accoustic_feature = pd.DataFrame(np.column_stack([processed_file_name, processed_min_pitch_list, processed_max_pitch_list, 
                                                                processed_mean_pitch_list, processed_sd_pitch_list, processed_min_intensity_list, 
                                                                processed_max_intensity_list, processed_mean_intensity_list, processed_sd_intensity_list, 
                                                                processed_jitter_list, processed_shimmer_list, processed_hnr_list, processed_speakingRate_list]),
                  columns = ['file_name', 'min_pitch', 'max_pitch', 'mean_pitch', 'sd_pitch',
                             'min_intensity', 'max_intensity', 'mean_intensity', 'sd_intensity', 'jitter',
                             'Shimmer', 'hnr', 'speaking_rate'])

# %%
audioInfo_prompt = overview_info[['file_name', 'prompt', 'audio_clipping:confidence', 'background_noise_audible:confidence', 'quiet_speaker:confidence']]
audioInfo_prompt.head()

# %%
processed_info_audio = processed_accoustic_feature.merge(audioInfo_prompt, on='file_name', how='left')
processed_info_audio.head()

# %%
processed_info_audio.to_csv("/Users/jifeng/Desktop/Medical Speech, Transcription, and Intent/processed_info_accoustic_feature.csv", index=False)
